# %%
from fetchopendata import fetch_road_network_info, fetch_abs_erp_lga2021_western_australia
# Out:
# c:\Users\e81005\Miniconda39\lib\site-packages\pandasdmx\remote.py:11: RuntimeWarning: optional dependency requests_cache is not installed; cache options to Session() have no effect
#   warn(

# %%
fetch_road_network_info(additional_params={"where":"ROAD='H001'"})
# Out:
# ...
#
#
# Download Completed. received 492 records
#      ROAD  START_SLK  END_SLK     CWY NETWORK_TYPE  START_TRUE_DIST  \
# 0    H001       0.00     0.03    Left   State Road             0.00
# 1    H001       0.03     0.08    Left   State Road             0.03
# 2    H001       0.08     0.10    Left   State Road             0.08
# 3    H001       0.10     0.24    Left   State Road             0.10
# 4    H001       0.24     0.27  Single   State Road             0.24
# ..    ...        ...      ...     ...          ...              ...
# 487  H001     403.57   403.69   Right   State Road           403.10
# 488  H001     403.69   404.01   Right   State Road           403.22
# 489  H001     404.01   404.05   Right   State Road           403.54
# 490  H001     404.05   404.09   Right   State Road           403.58
# 491  H001     404.09   404.18   Right   State Road           403.62
#
#      END_TRUE_DIST RA_NO
# 0             0.03    07
# 1             0.08    07
# 2             0.10    07
# ...

# %%
fetch_abs_erp_lga2021_western_australia()
# Out:
# 2022-06-09 11:45:00,955 pandasdmx.reader.sdmxml - DEBUG: Truncate sub-microsecond time in <Prepared>
# TIME_PERIOD                  REGION    FREQ     2010     2011     2012  \
# 0                            Albany  Annual  34518.0  34873.0  35643.0
# 1                          Armadale  Annual  61858.0  65395.0  69101.0
# 2                         Ashburton  Annual   9510.0  10227.0  11194.0
# 3            Augusta Margaret River  Annual  11951.0  12228.0  12870.0
# 4                        Bassendean  Annual  14897.0  15179.0  15527.0
# ..                              ...     ...      ...      ...      ...
# 132                     Wyalkatchem  Annual    526.0    542.0    539.0
# 133          Wyndham-East Kimberley  Annual   8111.0   8195.0   8228.0
# 134                          Yalgoo  Annual    377.0    417.0    425.0
# 135                         Yilgarn  Annual   1634.0   1675.0   1612.0
# 136                            York  Annual   3410.0   3462.0   3547.0
#
# ...
